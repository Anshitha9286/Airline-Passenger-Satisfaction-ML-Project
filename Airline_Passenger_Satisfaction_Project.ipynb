# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshitha9286/Airline-Passenger-Satisfaction-ML-Project/blob/main/Airline_Passenger_Satisfaction_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Airline Passenger Satisfaction Analysis and Prediction using Machine Learning
#
# # Domain
# Transportation and Logistics
#
# # Problem Statement
# Passenger satisfaction is an important factor for airlines to improve service quality and customer retention. This project aims to analyze passenger feedback and build machine learning models to predict whether a passenger is satisfied or dissatisfied based on travel details and service ratings.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-592f61b3-8beb-4c3e-be6c-ac8cde6d64d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-592f61b3-8beb-4c3e-be6c-ac8cde6d64d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("train.csv")

# %% [markdown]
# ## Data Understanding
#
# Before performing data preprocessing and building machine learning models, it is important to understand the dataset.

# %%
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 103899      103899  94171  Female  disloyal Customer   23  Business travel
# 103900      103900  73097    Male     Loyal Customer   49  Business travel
# 103901      103901  68825    Male  disloyal Customer   30  Business travel
# 103902      103902  54173  Female  disloyal Customer   22  Business travel
# 103903      103903  62567    Male     Loyal Customer   27  Business travel
#
#            Class  Flight Distance  Inflight wifi service  \
# 103899       Eco              192                      2
# 103900  Business             2347                      4
# 103901  Business             1995                      1
# 103902       Eco             1000                      1
# 103903  Business             1723                      1
#
#         Departure/Arrival time convenient  ...  Inflight entertainment  \
# 103899                                  1  ...                       2
# ...

# %%
df.shape
# Out:
# (103904, 25)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                             int64
# id                                     int64
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# ...

# %% [markdown]
# ## Observation
#
# - The dataset contains passenger information, travel details, service ratings, and satisfaction status.
# - It consists of both numerical and categorical features.
# - The target variable is satisfaction.

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# Unnamed: 0                           103904
# id                                   103904
# Gender                                    2
# Customer Type                             2
# Age                                      75
# Type of Travel                            2
# Class                                     3
# Flight Distance                        3802
# Inflight wifi service                     6
# Departure/Arrival time convenient         6
# Ease of Online booking                    6
# Gate location                             6
# Food and drink                            6
# Online boarding                           6
# Seat comfort                              6
# Inflight entertainment                    6
# On-board service                          6
# Leg room service                          6
# Baggage handling                          5
# Checkin service                           6
# Inflight service                          6
# ...

# %%
df['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='satisfaction', data=df)
plt.title('Passenger Satisfaction Distribution')
plt.show()

# %% [markdown]
# The dataset contains both satisfied and dissatisfied passengers. The classes appear reasonably balanced.

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['Age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['Flight Distance'])
plt.title('Boxplot of Flight Distance')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), annot=False, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
df['Arrival Delay in Minutes'] = df['Arrival Delay in Minutes'].fillna(
    df['Arrival Delay in Minutes'].median()
)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                           0
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
df.drop('id', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# Cleanliness                            int64
# Departure Delay in Minutes             int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])
df['Customer Type'] = le.fit_transform(df['Customer Type'])
df['Type of Travel'] = le.fit_transform(df['Type of Travel'])
df['satisfaction'] = le.fit_transform(df['satisfaction'])

# %%
df.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel     Class  Flight Distance  \
# 0       1              0   13               1  Eco Plus              460
# 1       1              1   25               0  Business              235
# 2       0              0   26               0  Business             1142
# 3       0              0   25               0  Business              562
# 4       1              0   61               0  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# ...

# %%
df = pd.get_dummies(df, columns=['Class'], drop_first=True)

# %%
df.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel  Flight Distance  \
# 0       1              0   13               1              460
# 1       1              1   25               0              235
# 2       0              0   26               0             1142
# 3       0              0   25               0              562
# 4       1              0   61               0              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  Food and drink  ...  \
# 0                       3              1               5  ...
# 1                       3              3               1  ...
# ...

# %%
X = df.drop('satisfaction', axis=1)
y = df['satisfaction']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X)

# %%
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

# %%
X_scaled.head()
# Out:
#      Gender  Customer Type       Age  Type of Travel  Flight Distance  \
# 0  1.015031      -0.472767 -1.745279        1.490614        -0.731539
# 1  1.015031       2.115208 -0.951360       -0.670865        -0.957184
# 2 -0.985192      -0.472767 -0.885200       -0.670865        -0.047584
# 3 -0.985192      -0.472767 -0.951360       -0.670865        -0.629246
# 4  1.015031      -0.472767  1.430397       -0.670865        -0.978244
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0               0.203579                           0.616172
# 1               0.203579                          -0.695245
# 2              -0.549533                          -0.695245
# 3              -0.549533                           1.271880
# 4               0.203579                          -0.039537
#
#    Ease of Online booking  Gate location  Food and drink  ...  \
# 0                0.173776      -1.547323        1.352264  ...
# ...

# %% [markdown]
# Train-Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)
print("Training Features :", X_train.shape)
print("Testing Features  :", X_test.shape)
print("Training Labels   :", y_train.shape)
print("Testing Labels    :", y_test.shape)
# Out:
# Training Features : (83123, 23)
# Testing Features  : (20781, 23)
# Training Labels   : (83123,)
# Testing Labels    : (20781,)

# %% [markdown]
# # Feature Selection
# Methods used:
# - SelectKBest
# - Random Forest Feature Importance

# %%
from sklearn.feature_selection import SelectKBest, f_classif
selector = SelectKBest(score_func=f_classif, k=10)
X_selected = selector.fit_transform(X_scaled, y)
selected_features = X_scaled.columns[selector.get_support()]
print("Selected Features:")
print(selected_features)
# Out:
# Selected Features:
# Index(['Type of Travel', 'Flight Distance', 'Inflight wifi service',
#        'Online boarding', 'Seat comfort', 'Inflight entertainment',
#        'On-board service', 'Leg room service', 'Cleanliness', 'Class_Eco'],
#       dtype='object')

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)
importance = pd.DataFrame({
    'Feature': X_scaled.columns,
    'Importance': rf.feature_importances_
})
importance = importance.sort_values(by='Importance', ascending=False)
importance.head(10)
# Out:
#                    Feature  Importance
# 10         Online boarding    0.178421
# 5    Inflight wifi service    0.143584
# 3           Type of Travel    0.111250
# 12  Inflight entertainment    0.062868
# 21               Class_Eco    0.061088
# 1            Customer Type    0.040851
# 4          Flight Distance    0.040512
# 11            Seat comfort    0.039585
# 7   Ease of Online booking    0.038355
# 14        Leg room service    0.038249

# %%
plt.figure(figsize=(10,6))
sns.barplot(
    x='Importance',
    y='Feature',
    data=importance.head(10)
)
plt.title("Top 10 Important Features")
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    RandomForestClassifier,
    GradientBoostingClassifier,
    AdaBoostClassifier
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report
)

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42),
    "KNN": KNeighborsClassifier(),
    "SVM": SVC(),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(random_state=42),
    "AdaBoost": AdaBoostClassifier(random_state=42),
    "MLP Classifier": MLPClassifier(max_iter=1000, random_state=42)
}

# %%
results = []

for name, model in models.items():

    # Train the model
    model.fit(X_train, y_train)

    # Predict
    y_pred = model.predict(X_test)

    # Calculate metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    # Store results
    results.append({
        "Model": name,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1 Score": f1
    })

    # Display results
    print("=" * 60)
    print(name)
    print("=" * 60)
    print("Accuracy :", round(accuracy, 4))
    print("Precision:", round(precision, 4))
    print("Recall   :", round(recall, 4))
    print("F1 Score :", round(f1, 4))

    print("\nConfusion Matrix")
    print(confusion_matrix(y_test, y_pred))

    print("\nClassification Report")
    print(classification_report(y_test, y_pred))
# Out:
# ...
# Logistic Regression
# ...
# Accuracy : 0.8766
# Precision: 0.8734
# Recall   : 0.8389
# F1 Score : 0.8558
#
# Confusion Matrix
# [[10610  1103]
#  [ 1461  7607]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89     11713
#            1       0.87      0.84      0.86      9068
#
#     accuracy                           0.88     20781
#    macro avg       0.88      0.87      0.87     20781
# weighted avg       0.88      0.88      0.88     20781
#
# ...
# Decision Tree
# ...
# Accuracy : 0.9437
# Precision: 0.9317
# Recall   : 0.94
# F1 Score : 0.9358
#
# Confusion Matrix
# [[11088   625]
#  [  544  8524]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95     11713
#            1       0.93      0.94      0.94      9068
#
#     accuracy                           0.94     20781
#    macro avg       0.94      0.94      0.94     20781
# ...

# %%
results_df = pd.DataFrame(results)
results_df = results_df.sort_values(by='Accuracy', ascending=False)
results_df
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score
# 2        Random Forest  0.961696   0.971608  0.939678  0.955376
# 8       MLP Classifier  0.959915   0.965623  0.941663  0.953492
# 4                  SVM  0.953708   0.960464  0.932289  0.946167
# 1        Decision Tree  0.943747   0.931687  0.940009  0.935829
# 6    Gradient Boosting  0.940763   0.946146  0.916409  0.931040
# 3                  KNN  0.928492   0.952171  0.880348  0.914852
# 7             AdaBoost  0.914489   0.903040  0.900750  0.901894
# 0  Logistic Regression  0.876618   0.873364  0.838884  0.855777
# 5          Naive Bayes  0.860546   0.859809  0.812969  0.835733

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5]
}
grid_search = GridSearchCV(
    estimator=RandomForestClassifier(random_state=42),
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [10, 20, None],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [100, 200]},
#              scoring='accuracy')

# %%
print("Best Parameters:")
print(grid_search.best_params_)
print("\nBest Cross Validation Accuracy:")
print(grid_search.best_score_)
# Out:
# Best Parameters:
# {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 200}
#
# Best Cross Validation Accuracy:
# 0.9613223899498505

# %%
best_rf = grid_search.best_estimator_
best_rf
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
y_pred = best_rf.predict(X_test)
print("Accuracy :", accuracy_score(y_test, y_pred))
print()
print(classification_report(y_test, y_pred))
# Out:
# Accuracy : 0.9615995380395553
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97     11713
#            1       0.97      0.94      0.96      9068
#
#     accuracy                           0.96     20781
#    macro avg       0.96      0.96      0.96     20781
# weighted avg       0.96      0.96      0.96     20781

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,5))

sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues'
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

plt.show()

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Predict probabilities
y_prob = best_rf.predict_proba(X_test)[:, 1]

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# Compute AUC
roc_auc = auc(fpr, tpr)

# Plot ROC Curve
plt.figure(figsize=(7,5))
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.3f})')
plt.plot([0,1], [0,1], linestyle='--')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Random Forest Classifier')
plt.legend(loc='lower right')

plt.show()

# %%
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(
    best_rf,
    X_scaled,
    y,
    cv=5
)
print(cv_scores)
print("Average Accuracy:", cv_scores.mean())
# Out:
# [0.9608296  0.96188826 0.95977094 0.96328377 0.96352262]
# Average Accuracy: 0.9618590397249209

# %%
import joblib
joblib.dump(best_rf, "Airline_Satisfaction_Model.pkl")
print("Model Saved Successfully")
# Out:
# Model Saved Successfully

# %%
sample = X_test.iloc[[0]]

prediction = best_rf.predict(sample)

print("Prediction:", prediction[0])
print("Actual:", y_test.iloc[0])
# Out:
# Prediction: 0
# Actual: 0

# %%
importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": best_rf.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

importance.head(10)
# Out:
#                    Feature  Importance
# 10         Online boarding    0.190972
# 5    Inflight wifi service    0.141895
# 3           Type of Travel    0.101171
# 21               Class_Eco    0.072437
# 12  Inflight entertainment    0.055281
# 14        Leg room service    0.041255
# 11            Seat comfort    0.039396
# 4          Flight Distance    0.038794
# 7   Ease of Online booking    0.037022
# 1            Customer Type    0.036050

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=importance.head(10),
    x="Importance",
    y="Feature"
)

plt.title("Top 10 Important Features")

plt.show()

# %% [markdown]
# # Conclusion
#
# Multiple machine learning classification models were developed and evaluated to predict airline passenger satisfaction.
#
# Among all the models, the Random Forest Classifier achieved the highest accuracy of approximately 96%, making it the best-performing model for this dataset.
#
# The project demonstrates that machine learning can effectively predict passenger satisfaction based on travel details and service quality, enabling airlines to improve customer experience and make data-driven decisions.
